# %%
import os.path
import os
import pandas as pd
import numpy as np

cwd = os.getcwd()

os.chdir('/Users/Eis4Elephant/Desktop')

# %%
with open('data.txt', 'r') as f:
    file = f.read()

# %%
print (file)
# Out:
# IDON’T do it for the money. I’ve got enough, much more than I’ll ever need. I do it to do it.
# Deals are my art form. Other people paint beautifully on canvas or write wonderful
# poetry. I like making deals, preferably big deals. That’s how I get my kicks.
# Most people are surprised by the way I work. I play it very loose. I don’t carry a briefcase. I try not to schedule too many meetings. I leave my door open. You can’t be imaginative or entrepreneurial if you’ve got too much structure. I prefer to come to work each day and just
# see what develops.
# There is no typical week in my life. I wake up most mornings very early, around six, and
# spend the first hour or so of each day reading the morning newspapers. I usually arrive at my office by nine, and I get on the phone. There’s rarely a day with fewer than fifty calls, and often it runs to over a hundred. In between, I have at least a dozen meetings. The majority occur on the spur of the moment, and few of them last longer than fifteen minutes. I rarely stop for lunch. I leave my office by six-thirty, but I frequently make calls from home until midnight, and all weekend long.
# It never stops, and I wouldn’t have it any other way. I try to learn from the past, but I plan for the future by focusing exclusively on the present. That’s where the fun is. And if it can’t be fun, what’s the point?

# %%
words= file.split(' ')
lines= file.split('\n')
lines
# Out:
# ['IDON’T do it for the money. I’ve got enough, much more than I’ll ever need. I do it to do it.',
#  'Deals are my art form. Other people paint beautifully on canvas or write wonderful',
#  'poetry. I like making deals, preferably big deals. That’s how I get my kicks.',
#  'Most people are surprised by the way I work. I play it very loose. I don’t carry a briefcase. I try not to schedule too many meetings. I leave my door open. You can’t be imaginative or entrepreneurial if you’ve got too much structure. I prefer to come to work each day and just',
#  'see what develops.',
#  'There is no typical week in my life. I wake up most mornings very early, around six, and',
#  'spend the first hour or so of each day reading the morning newspapers. I usually arrive at my office by nine, and I get on the phone. There’s rarely a day with fewer than fifty calls, and often it runs to over a hundred. In between, I have at least a dozen meetings. The majority occur on the spur of the moment, and few of them last longer than fifteen minutes. I rarely stop for lunch. I leave my office by six-thirty, but I frequently make calls from home until midnight, and all weekend long.',
#  'It never stops, and I wouldn’t have it any other way. I try to learn from the past, but I plan for the future by focusing exclusively on the present. That’s where the fun is. And if it can’t be fun, what’s the point?']

# %%
words= np.asarray(words)
len(np.unique(words))
# np.unique(words)
# Out:
# 165

# %%
# from keras.preprocessing.text import Tokenizer
# from keras.preprocessing.sequence import pad_sequences
# from keras.preprocessing.text import text_to_word_sequence


# # tokenizer = Tokenizer(num_words=None)
# # tokenizer.fit_on_texts(files)
# # sequences = tokenizer.texts_to_sequences(files)
# sequences= text_to_word_sequence(file, filters='!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~\t\n', lower=True, split=' ')
# print (len(np.unique(np.asarray(sequences))))
# len(sequences)
# word_index = tokenizer.word_index
# # print('Found %s unique tokens.' % len(word_index))
# Out:
# 157

# %%
chars = set(file)
words = set(file.split())
print ("total number of unique words", len(words))
print ("total number of unique chars", len(chars))
# Out:
# total number of unique words 171
# total number of unique chars 41

# %%
list_words=file.lower().split()
list_words
# Out:
# ['idon’t',
#  'do',
#  'it',
#  'for',
#  'the',
#  'money.',
#  'i’ve',
#  'got',
#  'enough,',
#  'much',
#  'more',
#  'than',
#  'i’ll',
#  'ever',
#  'need.',
#  'i',
#  'do',
#  'it',
#  'to',
#  'do',
#  'it.',
#  'deals',
#  'are',
#  'my',
#  'art',
#  'form.',
#  'other',
#  'people',
#  'paint',
#  'beautifully',
#  'on',
#  'canvas',
#  'or',
#  'write',
#  'wonderful',
#  'poetry.',
#  'i',
#  'like',
#  'making',
#  'deals,',
#  'preferably',
#  'big',
#  'deals.',
#  'that’s',
#  'how',
#  'i',
#  'get',
#  'my',
#  'kicks.',
#  'most',
#  'people',
#  'are',
#  'surprised',
#  'by',
#  'the',
#  'way',
#  'i',
#  'work.',
#  'i',
#  'play',
#  'it',
#  'very',
#  'loose.',
#  'i',
#  'don’t',
#  'carry',
#  'a',
#  'briefcase.',
#  'i',
#  'try',
#  'not',
#  'to',
#  'schedule',
#  'too',
#  'many',
#  'meetings.',
#  'i',
#  'leave',
#  'my',
#  'door',
#  'open.',
#  'you',
#  'can’t',
#  'be',
#  'imaginative',
#  'or',
#  'entrepreneurial',
#  'if',
#  'you’ve',
#  'got',
#  'too',
#  'much',
#  'structure.',
#  'i',
#  'prefer',
#  'to',
#  'come',
#  'to',
#  'work',
#  'each',
#  'day',
#  'and',
#  'just',
#  'see',
#  'what',
#  'develops.',
#  'there',
#  'is',
#  'no',
#  'typical',
#  'week',
#  'in',
#  'my',
#  'life.',
#  'i',
#  'wake',
#  'up',
#  'most',
#  'mornings',
#  'very',
#  'early,',
#  'around',
#  'six,',
#  'and',
#  'spend',
#  'the',
#  'first',
#  'hour',
#  'or',
#  'so',
#  'of',
#  'each',
#  'day',
#  'reading',
#  'the',
#  'morning',
#  'newspapers.',
#  'i',
#  'usually',
#  'arrive',
#  'at',
#  'my',
#  'office',
#  'by',
#  'nine,',
#  'and',
#  'i',
#  'get',
#  'on',
#  'the',
#  'phone.',
#  'there’s',
#  'rarely',
#  'a',
#  'day',
#  'with',
#  'fewer',
#  'than',
#  'fifty',
#  'calls,',
#  'and',
#  'often',
#  'it',
#  'runs',
#  'to',
#  'over',
#  'a',
#  'hundred.',
#  'in',
#  'between,',
#  'i',
#  'have',
#  'at',
#  'least',
#  'a',
#  'dozen',
#  'meetings.',
#  'the',
#  'majority',
#  'occur',
#  'on',
#  'the',
#  'spur',
#  'of',
#  'the',
#  'moment,',
#  'and',
#  'few',
#  'of',
#  'them',
#  'last',
#  'longer',
#  'than',
#  'fifteen',
#  'minutes.',
#  'i',
#  'rarely',
#  'stop',
#  'for',
#  'lunch.',
#  'i',
#  'leave',
#  'my',
#  'office',
#  'by',
#  'six-thirty,',
#  'but',
#  'i',
#  'frequently',
#  'make',
#  'calls',
#  'from',
#  'home',
#  'until',
#  'midnight,',
#  'and',
#  'all',
#  'weekend',
#  'long.',
#  'it',
#  'never',
#  'stops,',
#  'and',
#  'i',
#  'wouldn’t',
#  'have',
#  'it',
#  'any',
#  'other',
#  'way.',
#  'i',
#  'try',
#  'to',
#  'learn',
#  'from',
#  'the',
#  'past,',
#  'but',
#  'i',
#  'plan',
#  'for',
#  'the',
#  'future',
#  'by',
#  'focusing',
#  'exclusively',
#  'on',
#  'the',
#  'present.',
#  'that’s',
#  'where',
#  'the',
#  'fun',
#  'is.',
#  'and',
#  'if',
#  'it',
#  'can’t',
#  'be',
#  'fun,',
#  'what’s',
#  'the',
#  'point?']

# %%
word_indices = dict((c, i) for i, c in enumerate(words))
indices_word = dict((i, c) for i, c in enumerate(words))

# %%
# maxer=0
# max_seq=''
# for sequence in sequences:
#     if len(sequence) >maxer:
#         maxer=len(sequence)
#         max_seq=sequence
# maxer

# %%
for word in word_indices.keys():
    word_indices[word.replace("‘", '').replace("’", '').replace("'", '')]=word_indices.pop(word)

# %%
word_indices.keys()
# Out:
# dict_keys(['occur', 'The', 'big', 'very', 'fifteen', 'spend', 'present.', 'future', 'structure.', 'loose.', 'hundred.', 'dont', 'form.', 'longer', 'most', 'briefcase.', 'office', 'deals.', 'In', 'way', 'There', 'typical', 'stop', 'on', 'hour', 'them', 'canvas', 'day', 'come', 'nine,', 'got', 'see', 'if', 'youve', 'beautifully', 'lunch.', 'have', 'whats', 'poetry.', 'six-thirty,', 'more', 'try', 'last', 'midnight,', 'any', 'Other', 'first', 'develops.', 'frequently', 'until', 'wouldnt', 'no', 'of', 'people', 'fun', 'art', 'least', 'preferably', 'few', 'too', 'rarely', 'much', 'moment,', 'not', 'weekend', 'Deals', 'in', 'Ive', 'Theres', 'often', 'leave', 'open.', 'dozen', 'it', 'making', 'morning', 'fun,', 'surprised', 'stops,', 'many', 'the', 'between,', 'other', 'each', 'a', 'for', 'six,', 'way.', 'than', 'deals,', 'runs', 'exclusively', 'cant', 'You', 'is.', 'carry', 'focusing', 'newspapers.', 'do', 'fifty', 'all', 'so', 'And', 'enough,', 'to', 'at', 'arrive', 'meetings.', 'imaginative', 'wonderful', 'where', 'I', 'are', 'life.', 'how', 'early,', 'calls,', 'over', 'majority', 'calls', 'play', 'Ill', 'is', 'reading', 'entrepreneurial', 'fewer', 'long.', 'it.', 'around', 'Most', 'money.', 'never', 'point?', 'my', 'Thats', 'be', 'home', 'learn', 'make', 'by', 'work', 'or', 'kicks.', 'and', 'get', 'door', 'just', 'plan', 'week', 'but', 'from', 'past,', 'work.', 'up', 'write', 'need.', 'schedule', 'ever', 'mornings', 'wake', 'IDONT', 'spur', 'with', 'like', 'phone.', 'paint', 'minutes.', 'what', 'prefer', 'usually', 'It'])

# %%
maxlen = 10
step = 3

sentences = []
next_words = []
next_words = []
list_words = []

sentences2 = []
list_words = file.split()
for i in range(len( list_words)):
    list_words[i]=list_words[i].replace("‘", '').replace("’", '').replace("'", '')

for i in range(0, len(list_words) - maxlen, step):
    sentences2 = ' '.join(list_words[i: i + maxlen])
    sentences.append(sentences2)
    next_words.append((list_words[i + maxlen]))

print ('length of sentence list:', len(sentences))
print ("length of next_word list", len(next_words))
# Out:
# length of sentence list: 85
# length of next_word list 85

# %%
sequences=[]
y=[]
# y=np.zeros((len(sentences), len(words)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    sequence=[]
    for j, word in enumerate(sentence.split()):
        sequence.append(word_indices[word])
    sequences.append(sequence)
#     y[i, word_indices[next_words[i]]]=1
    y.append(word_indices[next_words[i]])

# %%
np.asarray(y).shape
# Out:
# (85,)

# %%
np.max(np.asarray(y))
# Out:
# 168

# %%
# Out:
# 85

# %%
sequences=np.asarray(sequences)

# %%
word_indices
# Out:
# {'And': 102,
#  'Deals': 65,
#  'I': 111,
#  'IDONT': 160,
#  'Ill': 121,
#  'In': 18,
#  'It': 170,
#  'Ive': 67,
#  'Most': 129,
#  'Other': 45,
#  'Thats': 134,
#  'The': 1,
#  'There': 20,
#  'Theres': 68,
#  'You': 93,
#  'a': 84,
#  'all': 100,
#  'and': 143,
#  'any': 44,
#  'are': 112,
#  'around': 128,
#  'arrive': 106,
#  'art': 55,
#  'at': 105,
#  'be': 135,
#  'beautifully': 34,
#  'between,': 81,
#  'big': 2,
#  'briefcase.': 15,
#  'but': 149,
#  'by': 139,
#  'calls': 119,
#  'calls,': 116,
#  'cant': 92,
#  'canvas': 26,
#  'carry': 95,
#  'come': 28,
#  'day': 27,
#  'deals,': 89,
#  'deals.': 17,
#  'develops.': 47,
#  'do': 98,
#  'dont': 11,
#  'door': 145,
#  'dozen': 72,
#  'each': 83,
#  'early,': 115,
#  'enough,': 103,
#  'entrepreneurial': 124,
#  'ever': 157,
#  'exclusively': 91,
#  'few': 58,
#  'fewer': 125,
#  'fifteen': 4,
#  'fifty': 99,
#  'first': 46,
#  'focusing': 96,
#  'for': 85,
#  'form.': 12,
#  'frequently': 48,
#  'from': 150,
#  'fun': 54,
#  'fun,': 76,
#  'future': 7,
#  'get': 144,
#  'got': 30,
#  'have': 36,
#  'home': 136,
#  'hour': 24,
#  'how': 114,
#  'hundred.': 10,
#  'if': 32,
#  'imaginative': 108,
#  'in': 66,
#  'is': 122,
#  'is.': 94,
#  'it': 73,
#  'it.': 127,
#  'just': 146,
#  'kicks.': 142,
#  'last': 42,
#  'learn': 137,
#  'least': 56,
#  'leave': 70,
#  'life.': 113,
#  'like': 163,
#  'long.': 126,
#  'longer': 13,
#  'loose.': 9,
#  'lunch.': 35,
#  'majority': 118,
#  'make': 138,
#  'making': 74,
#  'many': 79,
#  'meetings.': 107,
#  'midnight,': 43,
#  'minutes.': 166,
#  'moment,': 62,
#  'money.': 130,
#  'more': 40,
#  'morning': 75,
#  'mornings': 158,
#  'most': 14,
#  'much': 61,
#  'my': 133,
#  'need.': 155,
#  'never': 131,
#  'newspapers.': 97,
#  'nine,': 29,
#  'no': 51,
#  'not': 63,
#  'occur': 0,
#  'of': 52,
#  'office': 16,
#  'often': 69,
#  'on': 23,
#  'open.': 71,
#  'or': 141,
#  'other': 82,
#  'over': 117,
#  'paint': 165,
#  'past,': 151,
#  'people': 53,
#  'phone.': 164,
#  'plan': 147,
#  'play': 120,
#  'poetry.': 38,
#  'point?': 132,
#  'prefer': 168,
#  'preferably': 57,
#  'present.': 6,
#  'rarely': 60,
#  'reading': 123,
#  'runs': 90,
#  'schedule': 156,
#  'see': 31,
#  'six,': 86,
#  'six-thirty,': 39,
#  'so': 101,
#  'spend': 5,
#  'spur': 161,
#  'stop': 22,
#  'stops,': 78,
#  'structure.': 8,
#  'surprised': 77,
#  'than': 88,
#  'the': 80,
#  'them': 25,
#  'to': 104,
#  'too': 59,
#  'try': 41,
#  'typical': 21,
#  'until': 49,
#  'up': 153,
#  'usually': 169,
#  'very': 3,
#  'wake': 159,
#  'way': 19,
#  'way.': 87,
#  'week': 148,
#  'weekend': 64,
#  'what': 167,
#  'whats': 37,
#  'where': 110,
#  'with': 162,
#  'wonderful': 109,
#  'work': 140,
#  'work.': 152,
#  'wouldnt': 50,
#  'write': 154,
#  'youve': 33}

# %%
# for i, sentence in enumerate(sentences):
#     for t, word in enumerate(sentence.split()):
#         print (indices_word[t])
# Out:
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.
# occur
# The
# big
# very
# fifteen
# spend
# present.
# future
# structure.
# loose.

# %%
# X = np.zeros((len(sentences), maxlen, len(words)), dtype=np.bool)
# y = np.zeros((len(sentences), len(words)), dtype=np.bool)
# for i, sentence in enumerate(sentences):
#     for t, word in enumerate(sentence.split()):
#         X[i, t, word_indices[word]] = 1
#     y[i, word_indices[next_words[i]]] = 1

# X=[]
# y=[]
# for sentence in sentences:
#     for word in sentences.split():
#         X.append(embedding_matrix[])

# %%
# maxer=0
# max_word=''
# for word in word_index:
#     if len(word) >maxer:
#         maxer=len(word)
#         max_word=word
# maxer, max_word

# %%
# word_index['entrepreneurial']

# %%
# for word in np.unique(words):
#     if word not in word_index:
#         print (word)
# Out:
# And
# I
# IDON’T
# In
# I’ll
# I’ve
# Other
# That’s
# The
# There’s
# You
# and
# spend
# between,
# briefcase.
# calls,
# deals,
# deals.
# develops.
# There
# early,
# enough,
# form.
# fun,
# hundred.
# is.
# it.
# Deals
# just
# see
# kicks.
# Most
# life.
# long.
# It
# loose.
# lunch.
# meetings.
# midnight,
# minutes.
# moment,
# money.
# need.
# newspapers.
# nine,
# open.
# past,
# phone.
# point?
# present.
# six,
# six-thirty,
# stops,
# structure.
# way.
# wonderful
# poetry.
# work.

# %%
# data = pad_sequences(sequences, maxlen=len(max_seq))

# print('Shape of data tensor:', data.shape)

# data[2]

# %%
# test=np.asarray([1,2,3,4,5])
# test= test[:,-1]

# %%
# predictors, label = data[:,:-1],data[:,-1]

# %%
total_words= len(word_indices) + 1
total_words
# Out:
# 172

# %%
# import keras.utils as ku 

# label = ku.to_categorical(label, num_classes=total_words)

# %%
# maxer=0
# for array in data:
#     if np.sum(np.asarray(array)) >maxer:
#         maxer=np.sum(np.asarray(array))
#         print (array, maxer)

# %%
word_indices
# Out:
# {'And': 102,
#  'Deals': 65,
#  'I': 111,
#  'IDONT': 160,
#  'Ill': 121,
#  'In': 18,
#  'It': 170,
#  'Ive': 67,
#  'Most': 129,
#  'Other': 45,
#  'Thats': 134,
#  'The': 1,
#  'There': 20,
#  'Theres': 68,
#  'You': 93,
#  'a': 84,
#  'all': 100,
#  'and': 143,
#  'any': 44,
#  'are': 112,
#  'around': 128,
#  'arrive': 106,
#  'art': 55,
#  'at': 105,
#  'be': 135,
#  'beautifully': 34,
#  'between,': 81,
#  'big': 2,
#  'briefcase.': 15,
#  'but': 149,
#  'by': 139,
#  'calls': 119,
#  'calls,': 116,
#  'cant': 92,
#  'canvas': 26,
#  'carry': 95,
#  'come': 28,
#  'day': 27,
#  'deals,': 89,
#  'deals.': 17,
#  'develops.': 47,
#  'do': 98,
#  'dont': 11,
#  'door': 145,
#  'dozen': 72,
#  'each': 83,
#  'early,': 115,
#  'enough,': 103,
#  'entrepreneurial': 124,
#  'ever': 157,
#  'exclusively': 91,
#  'few': 58,
#  'fewer': 125,
#  'fifteen': 4,
#  'fifty': 99,
#  'first': 46,
#  'focusing': 96,
#  'for': 85,
#  'form.': 12,
#  'frequently': 48,
#  'from': 150,
#  'fun': 54,
#  'fun,': 76,
#  'future': 7,
#  'get': 144,
#  'got': 30,
#  'have': 36,
#  'home': 136,
#  'hour': 24,
#  'how': 114,
#  'hundred.': 10,
#  'if': 32,
#  'imaginative': 108,
#  'in': 66,
#  'is': 122,
#  'is.': 94,
#  'it': 73,
#  'it.': 127,
#  'just': 146,
#  'kicks.': 142,
#  'last': 42,
#  'learn': 137,
#  'least': 56,
#  'leave': 70,
#  'life.': 113,
#  'like': 163,
#  'long.': 126,
#  'longer': 13,
#  'loose.': 9,
#  'lunch.': 35,
#  'majority': 118,
#  'make': 138,
#  'making': 74,
#  'many': 79,
#  'meetings.': 107,
#  'midnight,': 43,
#  'minutes.': 166,
#  'moment,': 62,
#  'money.': 130,
#  'more': 40,
#  'morning': 75,
#  'mornings': 158,
#  'most': 14,
#  'much': 61,
#  'my': 133,
#  'need.': 155,
#  'never': 131,
#  'newspapers.': 97,
#  'nine,': 29,
#  'no': 51,
#  'not': 63,
#  'occur': 0,
#  'of': 52,
#  'office': 16,
#  'often': 69,
#  'on': 23,
#  'open.': 71,
#  'or': 141,
#  'other': 82,
#  'over': 117,
#  'paint': 165,
#  'past,': 151,
#  'people': 53,
#  'phone.': 164,
#  'plan': 147,
#  'play': 120,
#  'poetry.': 38,
#  'point?': 132,
#  'prefer': 168,
#  'preferably': 57,
#  'present.': 6,
#  'rarely': 60,
#  'reading': 123,
#  'runs': 90,
#  'schedule': 156,
#  'see': 31,
#  'six,': 86,
#  'six-thirty,': 39,
#  'so': 101,
#  'spend': 5,
#  'spur': 161,
#  'stop': 22,
#  'stops,': 78,
#  'structure.': 8,
#  'surprised': 77,
#  'than': 88,
#  'the': 80,
#  'them': 25,
#  'to': 104,
#  'too': 59,
#  'try': 41,
#  'typical': 21,
#  'until': 49,
#  'up': 153,
#  'usually': 169,
#  'very': 3,
#  'wake': 159,
#  'way': 19,
#  'way.': 87,
#  'week': 148,
#  'weekend': 64,
#  'what': 167,
#  'whats': 37,
#  'where': 110,
#  'with': 162,
#  'wonderful': 109,
#  'work': 140,
#  'work.': 152,
#  'wouldnt': 50,
#  'write': 154,
#  'youve': 33}

# %%
embeddings_index = {}
f = open('glove.twitter.27B.25d.txt')
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 1193514 word vectors.

# %%
embeddings_index
# Out:
# array([-0.77069  ,  0.12827  ,  0.33137  ,  0.0050893, -0.47605  ,
#        -0.50116  ,  1.858    ,  1.0624   , -0.56511  ,  0.13328  ,
#        -0.41918  , -0.14195  , -2.8555   , -0.57131  , -0.13418  ,
#        -0.44922  ,  0.48591  , -0.6479   , -0.84238  ,  0.61669  ,
#        -0.19824  , -0.57967  , -0.65885  ,  0.43928  , -0.50473  ],
#       dtype=float32)

# %%
EMBEDDING_DIM=25
embedding_matrix = np.zeros((total_words, EMBEDDING_DIM))
for word, i in word_indices.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # words not found in embedding index will be all-zeros.
        embedding_matrix[i] = embedding_vector

# %%
X=[]
for number in sequences:
    X.append(embedding_matrix[number])
# Out:
# [array([[ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00],
#         [ 1.64769995e+00,  1.29030004e-01,  7.69110024e-01,
#          -3.08539998e-02,  2.75059998e-01, -4.92980003e-01,
#           8.20599973e-01, -1.25589997e-01,  5.70680022e-01,
#          -7.98979998e-01, -1.69120002e+00, -1.76559997e+00,
#          -5.31860018e+00, -1.25109994e+00, -7.30130017e-01,
#          -9.06970024e-01, -1.09319997e+00, -5.36339998e-01,
#           1.79670006e-01, -1.62469995e+00, -2.91760010e-03,
#           1.31840003e+00,  4.55940008e-01,  3.68200004e-01,
#           8.75909984e-01],
#         [ 1.67579994e-01,  2.14340001e-01, -9.30859968e-02,
#           1.63790002e-01, -6.00009978e-01, -3.71030010e-02,
#           1.85769999e+00, -2.43059993e-01, -4.48639989e-01,
#           2.87339985e-01, -4.36089993e-01,  1.08389997e+00,
#          -6.03849983e+00, -1.48719996e-01,  3.18430007e-01,
#           8.26300010e-02,  4.75620002e-01, -5.00899971e-01,
#          -9.93840024e-02, -1.80340007e-01, -1.06140003e-01,
#           1.52380005e-01,  3.25320005e-01,  7.37950027e-01,
#          -4.08589989e-01],
#         [-2.17490003e-01,  4.51830000e-01, -2.32109994e-01,
#          -2.77810007e-01, -6.79769963e-02, -6.39509976e-01,
#           1.12179995e+00, -3.75360012e-01,  1.86759993e-01,
#          -5.08639991e-01,  1.64230000e-02, -1.33289993e-01,
#          -5.90299988e+00,  1.45960003e-01, -6.70310035e-02,
#          -6.61989987e-01, -1.73620000e-01, -8.72810006e-01,
#          -4.97709990e-01, -5.52890003e-01, -1.05149996e+00,
#          -1.84839994e-01, -3.08479995e-01, -4.47800010e-02,
#          -2.43579999e-01],
#         [-1.01669999e-02,  2.01939996e-02,  2.14729995e-01,
#           1.72889993e-01, -4.36589986e-01, -1.46870002e-01,
#           1.84290004e+00, -1.57529995e-01,  1.81869999e-01,
#          -3.17820013e-01,  6.83899969e-02,  5.17759979e-01,
#          -6.33710003e+00,  4.80659992e-01,  1.37769997e-01,
#          -4.85680014e-01,  3.89999986e-01, -1.95059995e-03,
#          -1.02179997e-01,  2.12620005e-01, -8.61459970e-01,
#           1.72629997e-01,  1.87830001e-01, -8.42499971e-01,
#          -3.12079996e-01],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00],
#         
#           1.79190004e+00, -6.08759999e-01, -5.47919989e-01,
#          -7.90589973e-02, -1.07420003e+00,  6.77670002e-01,
#          -4.25260019e+00, -3.56290013e-01, -3.98110002e-01,
#           8.30730021e-01,  1.54330000e-01, -9.83870029e-01,
#          -3.47130001e-01, -6.91829979e-01,  5.80879986e-01,
#           5.63910007e-01,  9.46280003e-01,  6.15970016e-01,
#           1.89260006e-01],
#         [-3.43499988e-01,  1.01380002e+00, -3.92309986e-02,
#          -6.17389977e-01, -1.29999995e-01,  6.59730017e-01,
#           1.18610001e+00, -1.16999999e-01, -6.14210010e-01,
#           3.99450004e-01, -3.38340014e-01,  5.46429992e-01,
#          -5.41989994e+00,  3.17140013e-01, -6.29719973e-01,
#          -4.96829987e-01,  3.81040007e-01, -5.29590011e-01,
#          -5.12740016e-01, -8.82740021e-01,  5.23999989e-01,
#           1.03199995e+00, -6.24159992e-01,  1.20279998e-01,
#          -1.06959999e-01],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#           0.00000000e+00],
#         [ 9.90830004e-01,  8.19260001e-01,  7.55180001e-01,
#           2.86139995e-01,  3.79900008e-01, -1.26120001e-01,
#           3.30769986e-01,  3.02670002e-02, -5.37949979e-01,
#          -6.37120008e-01, -1.29229999e+00, -6.44999981e-01,
#          -3.75979996e+00, -1.45070004e+00,  4.64590013e-01,
#           1.25090003e-01,  2.00130001e-01, -1.09770000e-01,
#          -3.60760003e-01, -2.15920001e-01,  7.07029998e-01,
#          -4.71679986e-01,  4.23949987e-01,  1.10940003e+00,
#          -3.86209995e-01],
#         [-1.01669999e-02,  2.01939996e-02,  2.14729995e-01,
#           1.72889993e-01, -4.36589986e-01, -1.46870002e-01,
#           1.84290004e+00, -1.57529995e-01,  1.81869999e-01,
#          -3.17820013e-01,  6.83899969e-02,  5.17759979e-01,
#          -6.33710003e+00,  4.80659992e-01,  1.37769997e-01,
#          -4.85680014e-01,  3.89999986e-01, -1.95059995e-03,
#          -1.02179997e-01,  2.12620005e-01, -8.61459970e-01,
#           1.72629997e-01,  1.87830001e-01, -8.42499971e-01,
#          -3.12079996e-01]])]

# %%
np.asarray(X).shape
# Out:
# (85, 10, 25)

# %%
embedding_matrix.shape
# Out:
# (172, 25)

# %%
len(embedding_matrix)
# Out:
# 172

# %%
len(word_indices)
# Out:
# 171

# %%
len(sentences)
# Out:
# 85

# %%
# embedding_matrix[word_indices['the']]
# Out:
# array([-1.01669999e-02,  2.01939996e-02,  2.14729995e-01,  1.72889993e-01,
#        -4.36589986e-01, -1.46870002e-01,  1.84290004e+00, -1.57529995e-01,
#         1.81869999e-01, -3.17820013e-01,  6.83899969e-02,  5.17759979e-01,
#        -6.33710003e+00,  4.80659992e-01,  1.37769997e-01, -4.85680014e-01,
#         3.89999986e-01, -1.95059995e-03, -1.02179997e-01,  2.12620005e-01,
#        -8.61459970e-01,  1.72629997e-01,  1.87830001e-01, -8.42499971e-01,
#        -3.12079996e-01])

# %%
# from keras.layers import Embedding

# # embedding_layer = Embedding(len(word_index) + 1,
# #                             EMBEDDING_DIM,
# #                             weights=[embedding_matrix],
# #                             input_length=max_seq,
# #                             trainable=False)

# %%
# word_index
# Out:
# {'a': 5,
#  'b': 21,
#  'c': 17,
#  'd': 13,
#  'e': 1,
#  'f': 14,
#  'g': 19,
#  'h': 10,
#  'i': 4,
#  'j': 25,
#  'k': 23,
#  'l': 9,
#  'm': 15,
#  'n': 6,
#  'o': 3,
#  'p': 16,
#  'q': 27,
#  'r': 7,
#  's': 8,
#  't': 2,
#  'u': 12,
#  'v': 20,
#  'w': 18,
#  'x': 24,
#  'y': 11,
#  'z': 26,
#  '’': 22}

# %%
# max_seq_len= len(max_seq)
# max_seq_len
# Out:
# 96

# %%
embedding_matrix.shape
# Out:
# (172, 25)

# %%
np.asarray(X).shape
# Out:
# (85, 10, 25)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import Embedding
from keras.layers import Dropout
from keras.layers import LSTM
from keras.layers import Input
# embedding_layer= Embedding(total_words, EMBEDDING_DIM, weights=[embedding_matrix],input_length=max_seq,trainable=False)
# sequence_input = Input(shape=(max_seq,), dtype='int32')
# embedded_sequences= embedding_layer(sequence_input)
model=Sequential()
# e=Embedding(total_words, EMBEDDING_DIM, weights=[embedding_matrix],input_length=maxlen,trainable=False)
# model.add(e)
model.add(LSTM(100, input_shape=(maxlen, EMBEDDING_DIM)))
# model.add(Dropout(0.1))
# model.add(Flatten())
model.add(Dense(total_words, activation="softmax"))
model.compile(loss='categorical_crossentropy', optimizer='adam')
model.summary()

# model.add(LSTM(128, input_shape=(maxlen, len(chars))))
# model.add(Dense(len(chars), activation='softmax'))

# optimizer = RMSprop(lr=0.01)
# model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_30 (LSTM)               (None, 100)               50400
# _________________________________________________________________
# dense_22 (Dense)             (None, 172)               17372
# =================================================================
# Total params: 67,772
# Trainable params: 67,772
# Non-trainable params: 0
# _________________________________________________________________

# %%
X=np.asarray(X)
X.shape
# Out:
# (85, 10, 25)

# %%
y.shape
# Out:
# (85, 171)

# %%
model.fit(X, y, epochs=2, verbose=5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-439-8bbeb7c226c7> in <module>()
# ----> 1 model.fit(X, y, epochs=2, verbose=5)
#
# /anaconda3/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#     950             sample_weight=sample_weight,
#     951             class_weight=class_weight,
# --> 952             batch_size=batch_size)
#     953         # Prepare validation data.
#     954         do_validation = False
#
# /anaconda3/lib/python3.6/site-packages/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     787                 feed_output_shapes,
#     788                 check_batch_axis=False,  # Don't enforce the batch size.
# --> 789                 exception_prefix='target')
#     790
#     791             # Generate sample-wise weight values given the `sample_weight` and
#
# /anaconda3/lib/python3.6/site-packages/keras/engine/training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     136                             ': expected ' + names[i] + ' to have shape ' +
#     137                             str(shape) + ' but got array with shape ' +
# --> 138                             str(data_shape))
#     139     return data
#     140
#
# ValueError: Error when checking target: expected dense_22 to have shape (172,) but got array with shape (1,)

# %%
np.asarray(sequences).shape
# Out:
# (85, 10)

# %%
predictors.shape
# Out:
# (8, 95)

# %%
label.shape
# Out:
# (8,)
